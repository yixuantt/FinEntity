# %%
## entity-level
from example.finentity_lstm import entity_corr
entity_corr('btc')
# Out:
# *** entity_dict: ['btc', 'bitcoin', 'xbt'] ***
# from  2022-05-20 20:07:13  to  2023-02-01 23:00:13
# MIC 0.2547824133550648

# %%
from example.finentity_lstm import entity_corr
entity_corr('eth')
# Out:
# *** entity_dict: ['ethereum', 'eth'] ***
# from  2022-05-20 22:20:47  to  2023-02-01 23:25:47
# MIC 0.24236362150788726

# %%
from example.finentity_lstm import entity_corr
entity_corr('doge')
# Out:
# *** entity_dict: ['dogecoin', 'doge'] ***
# from  2022-05-22 15:00:00  to  2023-02-01 18:00:44
# MIC 0.19535227350950163

# %%
from example.finentity_lstm import entity_corr
entity_corr('xrp')
# Out:
# *** entity_dict: ['xrp', 'ripple'] ***
# from  2022-05-21 14:14:04  to  2023-02-01 15:30:00
# MIC 0.24495231877490467

# %%
## sequence level
from example.finbert_tone_lstm import get_tone_corr
get_tone_corr('btc')
# Out:
# ***load the data from disk***
# MIC 0.23879782773521208

# %%
from example.finbert_tone_lstm import get_tone_corr
get_tone_corr('eth')
# Out:
# ***load the data from disk***
# MIC 0.19217111514907617

# %%
from example.finbert_tone_lstm import get_tone_corr
get_tone_corr('doge')
# Out:
# ***load the data from disk***
# MIC 0.1852328644283493

# %%
from example.finbert_tone_lstm import get_tone_corr
get_tone_corr('xrp')
# Out:
# ***load the data from disk***
# MIC 0.2312628855715318
